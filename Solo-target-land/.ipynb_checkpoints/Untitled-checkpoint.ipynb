# %%
import os
import subprocess
import time
import signal
import vlc_config as VLC
import ai_image_analyzer as AImage


def newest(path):
    files = os.listdir(path)
    filtered_files = filter(lambda x: ".png" in x and ".swp" not in x, files)
    paths = [os.path.join(path, basename) for basename in filtered_files]
    deleteThis = "rm -r " + deletefiles(paths)
    return max(paths, key=os.path.getctime), deleteThis

def deletefiles(paths):
    picts = ""
    for x in range(0,len(paths)):
        picts = picts + " " + paths[x]
    return picts

AiModel = AImage.ai_image_analyzer()
ncPro = subprocess.Popen("nc 10.1.1.1 5502", shell=True, stdout=subprocess.PIPE, preexec_fn=os.setsid)
vlcPro = subprocess.Popen(VLC.VLC_START, shell=True, stdout=subprocess.PIPE, preexec_fn=os.setsid)
time.sleep(3)
x=1
while(vlcPro.poll() == None):

    sc_image, cleanFiles = newest(VLC.SC_PATH)

    print("File" + str(x) + "= " + sc_image)

    res = AiModel.isTarget(sc_image)
    if res:
        print("File" + sc_image + "is: " + "target")
    else:
        print("File" + sc_image + "is: " + "not target")

    x += 1
    #subprocess.Popen(cleanFiles, shell=True, stdout=subprocess.PIPE)

    time.sleep(1)
if(ncPro.poll() == None):
    os.killpg(os.getpgid(ncPro.pid), signal.SIGTERM)
if(vlcPro.poll() == None):
    os.killpg(os.getpgid(vlcPro.pid), signal.SIGTERM)
exit(1)
# Out:
# Using TensorFlow backend.
# File1= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene02251.png
# Test
# [[ 0.07883766  0.92116231]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene02251.pngis: not target
# File2= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00031.png
# Test
# [[ 0.306768    0.69323194]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00031.pngis: not target
# File3= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00091.png
# Test
# [[ 0.07560475  0.92439526]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00091.pngis: not target
# File4= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00151.png
# Test
# [[ 0.11487247  0.88512754]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00151.pngis: not target
# File5= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00241.png
# Test
# [[ 0.29524842  0.70475155]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00241.pngis: not target
# File6= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00301.png
# Test
# [[ 0.1236165   0.87638348]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00301.pngis: not target
# File7= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00391.png
# Test
# [[ 0.06043083  0.93956918]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00391.pngis: not target
# File8= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00451.png
# Test
# [[ 0.25229493  0.7477051 ]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00451.pngis: not target
# File9= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00511.png
# Test
# [[ 0.91883469  0.08116532]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00511.pngis: target
# File10= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00571.png
# Test
# [[ 0.84578425  0.15421578]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00571.pngis: target
# File11= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00661.png
# Test
# [[ 0.39637846  0.60362154]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00661.pngis: not target
# File12= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00721.png
# Test
# [[ 0.76488948  0.23511049]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00721.pngis: target
# File13= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00781.png
# Test
# [[ 0.76929641  0.23070358]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00781.pngis: target
# File14= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00841.png
# Test
# [[ 0.98609483  0.01390518]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00841.pngis: target
# File15= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00931.png
# Test
# [[ 0.79479897  0.20520104]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00931.pngis: target
# File16= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00991.png
# Test
# [[ 0.7721464  0.2278536]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00991.pngis: target
# File17= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene01051.png
# Test
# [[ 0.0890334   0.91096663]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene01051.pngis: not target
# File18= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene01111.png
# Test
# [[ 0.54453236  0.45546764]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene01111.pngis: target
# File19= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene01201.png
# Test
# [[ 0.65767491  0.34232509]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene01201.pngis: target
# File20= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene01261.png
# Test
# [[ 0.18644442  0.81355554]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene01261.pngis: not target
# File21= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene01321.png
# Test
# [[ 0.27833939  0.72166061]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene01321.pngis: not target
# File22= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene01381.png
# Test
# [[ 0.25569579  0.74430424]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene01381.pngis: not target
# File23= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene01471.png
# Test
# [[ 0.4712483   0.52875167]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene01471.pngis: not target
# File24= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene01531.png
# Test
# [[ 0.07977006  0.92022991]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene01531.pngis: not target
# File25= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene01591.png
# Test
# [[ 0.51908445  0.48091552]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene01591.pngis: target
# File26= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene01651.png
# Test
# [[ 0.24568696  0.75431299]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene01651.pngis: not target
# File27= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene01741.png
# Test
# [[ 0.18801482  0.81198514]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene01741.pngis: not target
# File28= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene01801.png
# Test
# [[ 0.80946404  0.19053596]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene01801.pngis: target
# File29= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene01861.png
# Test
# [[ 0.59443313  0.40556681]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene01861.pngis: target
# File30= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene01921.png
# Test
# [[ 0.09682098  0.90317899]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene01921.pngis: not target
# File31= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene01981.png
# Test
# [[ 0.26599526  0.7340048 ]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene01981.pngis: not target
# File32= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene02071.png
# Test
# [[ 0.45710239  0.54289764]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene02071.pngis: not target
# File33= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene02131.png
# Test
# [[ 0.44556221  0.55443776]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene02131.pngis: not target
# File34= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene02191.png
# Test
# [[ 0.76026958  0.23973037]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene02191.pngis: target
# File35= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene02251.png
# Test
# [[ 0.06055317  0.93944681]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene02251.pngis: not target
# File36= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene02341.png
# Test
# [[ 0.97636706  0.02363294]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene02341.pngis: target
# File37= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene02401.png
# Test
# [[ 0.84593862  0.15406136]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene02401.pngis: target
# File38= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene02461.png
# Test
# [[ 0.83063686  0.16936323]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene02461.pngis: target
# File39= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene02551.png
# Test
# [[ 0.7377829  0.2622171]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene02551.pngis: target
