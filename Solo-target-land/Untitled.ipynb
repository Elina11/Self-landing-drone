# %%
import os
import subprocess
import time
import signal
import vlc_config as VLC
import ai_image_analyzer as AImage


def newest(path):
    files = os.listdir(path)
    filtered_files = filter(lambda x: ".png" in x and ".swp" not in x, files)
    paths = [os.path.join(path, basename) for basename in filtered_files]
    deleteThis = "rm -r " + deletefiles(paths)
    return max(paths, key=os.path.getctime), deleteThis

def deletefiles(paths):
    picts = ""
    for x in range(0,len(paths)):
        picts = picts + " " + paths[x]
    return picts

AiModel = AImage.ai_image_analyzer()

vlcPro = subprocess.Popen(VLC.VLC_START, shell=True, stdout=subprocess.PIPE, preexec_fn=os.setsid)
time.sleep(2)
x=1
while(vlcPro.poll() == None):

    sc_image, cleanFiles = newest(VLC.SC_PATH)

    print("File" + str(x) + "= " + sc_image)

    res = AiModel.isTarget(sc_image)

    print("File" + sc_image + "is: " + str(res))

    x += 1
    #subprocess.Popen(cleanFiles, shell=True, stdout=subprocess.PIPE)

    time.sleep(1)

if(vlcPro.poll() == None):
    os.killpg(os.getpgid(vlcPro.pid), signal.SIGTERM)
exit(1)
# Out:
# Using TensorFlow backend.
# File1= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene02251.png
# Test
# [[ 0.07883766  0.92116231]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene02251.pngis: False
# File2= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00061.png
# Test
# [[ 0.09868007  0.90131992]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00061.pngis: False
# File3= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00121.png
# Test
# [[ 0.06943422  0.93056583]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00121.pngis: False
# File4= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00181.png
# Test
# [[ 0.50093108  0.49906898]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00181.pngis: True
# File5= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00241.png
# Test
# [[ 0.35985684  0.64014322]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00241.pngis: False
# File6= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00331.png
# Test
# [[ 0.13441908  0.86558092]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00331.pngis: False
# File7= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00391.png
# Test
# [[ 0.05611853  0.94388151]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00391.pngis: False
# File8= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00451.png
# Test
# [[ 0.3096469   0.69035316]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00451.pngis: False
# File9= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00541.png
# Test
# [[ 0.88253862  0.11746142]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00541.pngis: True
# File10= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00601.png
# Test
# [[ 0.96259046  0.03740961]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00601.pngis: True
# File11= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00661.png
# Test
# [[ 0.52022737  0.47977269]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00661.pngis: True
# File12= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00721.png
# Test
# [[ 0.81529754  0.18470249]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00721.pngis: True
# File13= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00781.png
# Test
# [[ 0.6583913  0.3416087]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00781.pngis: True
# File14= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00871.png
# Test
# [[ 0.58245653  0.41754338]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00871.pngis: True
# File15= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00931.png
# Test
# [[ 0.79734391  0.20265608]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00931.pngis: True
# File16= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00991.png
# Test
# [[ 0.88736767  0.11263236]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene00991.pngis: True
# File17= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene01051.png
# Test
# [[ 0.15983942  0.84016061]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene01051.pngis: False
# File18= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene01141.png
# Test
# [[ 0.79837519  0.20162483]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene01141.pngis: True
# File19= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene01201.png
# Test
# [[ 0.69005299  0.30994698]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene01201.pngis: True
# File20= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene01261.png
# Test
# [[ 0.02495901  0.97504097]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene01261.pngis: False
# File21= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene01321.png
# Test
# [[ 0.54686767  0.45313236]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene01321.pngis: True
# File22= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene01411.png
# Test
# [[ 0.08011434  0.91988564]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene01411.pngis: False
# File23= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene01471.png
# Test
# [[ 0.26169914  0.73830092]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene01471.pngis: False
# File24= /Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene01531.png
# Test
# [[ 0.05602065  0.94397932]]
# File/Users/elinasuslova/pythonDirectory/target-landing-drone/Solo-target-land/in_images/scene01531.pngis: False
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-e9386ccf0771> in <module>()
#      38     #subprocess.Popen(cleanFiles, shell=True, stdout=subprocess.PIPE)
#      39
# ---> 40     time.sleep(1)
#      41
#      42 if(vlcPro.poll() == None):
#
# KeyboardInterrupt:
